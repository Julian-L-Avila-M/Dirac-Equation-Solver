# %%
import dirac_solver

# %% [markdown]
# #### Initial state

# %% [markdown]
# hiperparametros:
# dirac_solver.GaussianWavePacket(momentum,mass,pached_width,spin-orientation)

# %%
initial_state = dirac_solver.GaussianWavePacket(momentum=[1,0,0], mass=1.0, packet_width=1.0, spin_orientation='up_z')
# Out:
# Objeto creado (falta aplicarle la geometria)

# %% [markdown]
# #### Geometry

# %%
geo = dirac_solver.Interval1D(-1,1)

# %% [markdown]
# #### simulation

# %%
simulation = dirac_solver.DiracSolver()

run =  simulation.run_simulation

plot = simulation.plot_probability_density
