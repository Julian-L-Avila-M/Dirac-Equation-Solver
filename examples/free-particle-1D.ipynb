# %% [markdown]
# # 1D Free Particle Simulation

# %%
import sys
sys.path.append('..')
import numpy as np
from dirac_solver.geometry import Grid
from dirac_solver.initial_state import GaussianPacket, ConstantSpinor
from dirac_solver.core import DiracProblemBuilder, DiracSolver
from dirac_solver import _core

# %% [markdown]
# ## 1. Set up the Simulation Parameters

# %%
shape = (400,)
spacing = (0.1,)
grid = Grid(shape, spacing)

# %%
constant_spinor = ConstantSpinor(momentum=[5, 0, 0])
initial_state = GaussianPacket(constant_spinor, center=[0, 0, 0], spatial_width=1.0)

# %%
potential = _core.FreeParticle()
boundary_condition = _core.PeriodicBoundary()

# %% [markdown]
# ## 2. Build and Run the Simulation

# %%
problem = DiracProblemBuilder() \
    .set_grid(grid) \
    .set_initial_state(initial_state) \
    .set_potential(potential) \
    .set_boundary_condition(boundary_condition) \
    .set_time_parameters(time_step=0.001, total_time=2.0) \
    .build()

# %%
solver = DiracSolver(problem)
# Out:
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.

# %%
solver.run_simulation()
# Out:
# Ejecutando simulación por 2000 pasos...
#   Paso 10/2000 completado.
#   Paso 20/2000 completado.
#   Paso 30/2000 completado.
#   Paso 40/2000 completado.
#   Paso 50/2000 completado.
#   Paso 60/2000 completado.
#   Paso 70/2000 completado.
#   Paso 80/2000 completado.
#   Paso 90/2000 completado.
#   Paso 100/2000 completado.
#   Paso 110/2000 completado.
#   Paso 120/2000 completado.
#   Paso 130/2000 completado.
#   Paso 140/2000 completado.
#   Paso 150/2000 completado.
#   Paso 160/2000 completado.
#   Paso 170/2000 completado.
#   Paso 180/2000 completado.
#   Paso 190/2000 completado.
#   Paso 200/2000 completado.
#   Paso 210/2000 completado.
#   Paso 220/2000 completado.
#   Paso 230/2000 completado.
#   Paso 240/2000 completado.
#   Paso 250/2000 completado.
#   Paso 260/2000 completado.
#   Paso 270/2000 completado.
#   Paso 280/2000 completado.
#   Paso 290/2000 completado.
#   Paso 300/2000 completado.
#   Paso 310/2000 completado.
#   Paso 320/2000 completado.
#   Paso 330/2000 completado.
#   Paso 340/2000 completado.
#   Paso 350/2000 completado.
#   Paso 360/2000 completado.
#   Paso 370/2000 completado.
#   Paso 380/2000 completado.
#   Paso 390/2000 completado.
#   Paso 400/2000 completado.
#   Paso 410/2000 completado.
#   Paso 420/2000 completado.
#   Paso 430/2000 completado.
#   Paso 440/2000 completado.
#   Paso 450/2000 completado.
#   Paso 460/2000 completado.
#   Paso 470/2000 completado.
#   Paso 480/2000 completado.
#   Paso 490/2000 completado.
#   Paso 500/2000 completado.
#   Paso 510/2000 completado.
#   Paso 520/2000 completado.
#   Paso 530/2000 completado.
#   Paso 540/2000 completado.
#   Paso 550/2000 completado.
#   Paso 560/2000 completado.
#   Paso 570/2000 completado.
#   Paso 580/2000 completado.
#   Paso 590/2000 completado.
#   Paso 600/2000 completado.
#   Paso 610/2000 completado.
#   Paso 620/2000 completado.
#   Paso 630/2000 completado.
#   Paso 640/2000 completado.
#   Paso 650/2000 completado.
#   Paso 660/2000 completado.
#   Paso 670/2000 completado.
#   Paso 680/2000 completado.
#   Paso 690/2000 completado.
#   Paso 700/2000 completado.
#   Paso 710/2000 completado.
#   Paso 720/2000 completado.
#   Paso 730/2000 completado.
#   Paso 740/2000 completado.
#   Paso 750/2000 completado.
#   Paso 760/2000 completado.
#   Paso 770/2000 completado.
#   Paso 780/2000 completado.
#   Paso 790/2000 completado.
#   Paso 800/2000 completado.
#   Paso 810/2000 completado.
#   Paso 820/2000 completado.
#   Paso 830/2000 completado.
#   Paso 840/2000 completado.
#   Paso 850/2000 completado.
#   Paso 860/2000 completado.
#   Paso 870/2000 completado.
#   Paso 880/2000 completado.
#   Paso 890/2000 completado.
#   Paso 900/2000 completado.
#   Paso 910/2000 completado.
#   Paso 920/2000 completado.
#   Paso 930/2000 completado.
#   Paso 940/2000 completado.
#   Paso 950/2000 completado.
#   Paso 960/2000 completado.
#   Paso 970/2000 completado.
#   Paso 980/2000 completado.
#   Paso 990/2000 completado.
#   Paso 1000/2000 completado.
#   Paso 1010/2000 completado.
#   Paso 1020/2000 completado.
#   Paso 1030/2000 completado.
#   Paso 1040/2000 completado.
#   Paso 1050/2000 completado.
#   Paso 1060/2000 completado.
#   Paso 1070/2000 completado.
#   Paso 1080/2000 completado.
#   Paso 1090/2000 completado.
#   Paso 1100/2000 completado.
#   Paso 1110/2000 completado.
#   Paso 1120/2000 completado.
#   Paso 1130/2000 completado.
#   Paso 1140/2000 completado.
#   Paso 1150/2000 completado.
#   Paso 1160/2000 completado.
#   Paso 1170/2000 completado.
#   Paso 1180/2000 completado.
#   Paso 1190/2000 completado.
#   Paso 1200/2000 completado.
#   Paso 1210/2000 completado.
#   Paso 1220/2000 completado.
#   Paso 1230/2000 completado.
#   Paso 1240/2000 completado.
#   Paso 1250/2000 completado.
#   Paso 1260/2000 completado.
#   Paso 1270/2000 completado.
#   Paso 1280/2000 completado.
#   Paso 1290/2000 completado.
#   Paso 1300/2000 completado.
#   Paso 1310/2000 completado.
#   Paso 1320/2000 completado.
#   Paso 1330/2000 completado.
#   Paso 1340/2000 completado.
#   Paso 1350/2000 completado.
#   Paso 1360/2000 completado.
#   Paso 1370/2000 completado.
#   Paso 1380/2000 completado.
#   Paso 1390/2000 completado.
#   Paso 1400/2000 completado.
#   Paso 1410/2000 completado.
#   Paso 1420/2000 completado.
#   Paso 1430/2000 completado.
#   Paso 1440/2000 completado.
#   Paso 1450/2000 completado.
#   Paso 1460/2000 completado.
#   Paso 1470/2000 completado.
#   Paso 1480/2000 completado.
#   Paso 1490/2000 completado.
#   Paso 1500/2000 completado.
#   Paso 1510/2000 completado.
#   Paso 1520/2000 completado.
#   Paso 1530/2000 completado.
#   Paso 1540/2000 completado.
#   Paso 1550/2000 completado.
#   Paso 1560/2000 completado.
#   Paso 1570/2000 completado.
#   Paso 1580/2000 completado.
#   Paso 1590/2000 completado.
#   Paso 1600/2000 completado.
#   Paso 1610/2000 completado.
#   Paso 1620/2000 completado.
#   Paso 1630/2000 completado.
#   Paso 1640/2000 completado.
#   Paso 1650/2000 completado.
#   Paso 1660/2000 completado.
#   Paso 1670/2000 completado.
#   Paso 1680/2000 completado.
#   Paso 1690/2000 completado.
#   Paso 1700/2000 completado.
#   Paso 1710/2000 completado.
#   Paso 1720/2000 completado.
#   Paso 1730/2000 completado.
#   Paso 1740/2000 completado.
#   Paso 1750/2000 completado.
#   Paso 1760/2000 completado.
#   Paso 1770/2000 completado.
#   Paso 1780/2000 completado.
#   Paso 1790/2000 completado.
#   Paso 1800/2000 completado.
#   Paso 1810/2000 completado.
#   Paso 1820/2000 completado.
#   Paso 1830/2000 completado.
#   Paso 1840/2000 completado.
#   Paso 1850/2000 completado.
#   Paso 1860/2000 completado.
#   Paso 1870/2000 completado.
#   Paso 1880/2000 completado.
#   Paso 1890/2000 completado.
#   Paso 1900/2000 completado.
#   Paso 1910/2000 completado.
#   Paso 1920/2000 completado.
#   Paso 1930/2000 completado.
#   Paso 1940/2000 completado.
#   Paso 1950/2000 completado.
#   Paso 1960/2000 completado.
#   Paso 1970/2000 completado.
#   Paso 1980/2000 completado.
#   Paso 1990/2000 completado.
#   Paso 2000/2000 completado.
# Simulación finalizada.

# %% [markdown]
# ## 3. Visualize the Results

# %%
solver.plot_probability_density()
# Out:
# Graficando densidad de probabilidad...
