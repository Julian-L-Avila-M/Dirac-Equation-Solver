# %% [markdown]
# # 1D, 2D and 3D Simulation and Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
from dirac_solver.geometry import Grid
from dirac_solver.initial_state import GaussianPacket
from dirac_solver.core import DiracSolver, DiracProblemBuilder
from dirac_solver.storage import HDF5Storage
from dirac_solver import _core, electron_mass
from dirac_solver.initial_state import ConstantSpinor
from dirac_solver.storage import create_animation

# %% [markdown]
# ## 1D Simulation with periodic and absorbing  Boundary and each potential

# %%
# ==========================
# 1. Grid 1D
# ==========================
grid_1d = Grid(
    shape=(400,),         # 400 puntos
    spacing=(0.05,)       # dx = 0.05
)

# ==========================
# 2. Estado inicial
# ==========================
spinor = ConstantSpinor(momentum=[5.0, 0.0, 0.0])   # el p2 y p3 se ignoran
initial_state_1d = GaussianPacket(spinor, spatial_width=1.0)

# ==========================
# 3. Potencial 1D
# ==========================
def harmonic_1d(r):
    x = r[0]
    return 0.5 * x*x         # V(x) = x²/2

potential_1d = _core.ScalarPotential(harmonic_1d)

# ==========================
# 4. Frontera
# ==========================
boundary_1d = _core.AbsorbingBoundary(strength=0.5)

# ==========================
# 5. Construir el problema
# ==========================
builder_1d = DiracProblemBuilder()
problem_1d = (
    builder_1d
    .set_grid(grid_1d)
    .set_initial_state(initial_state_1d)
    .set_potential(potential_1d)
    .set_boundary_condition(boundary_1d)
    .set_time_parameters(time_step=0.01, total_time=10.0)
    .build()
)

# ==========================
# 6. Almacenamiento HDF5
# ==========================
storage_1d = HDF5Storage(
    filepath="1DAbsorbingscalar.hdf5",
    problem=problem_1d
)

# ==========================
# 7. Ejecutar la simulación
# ==========================
solver_1d = DiracSolver(problem_1d)
solver_1d.run_simulation(storage_handler=storage_1d, save_every_n_steps=5)

# Cerrar archivo (por seguridad)
storage_1d.close()
create_animation('1DAbsorbingscalar.hdf5', '1DAbsorbingscalar.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 1DAbsorbingscalar.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 0.14 segundos.
# Datos guardados y archivo cerrado: 1DAbsorbingscalar.hdf5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 59
#      57 # Cerrar archivo (por seguridad)
#      58 storage_1d.close()
# ---> 59 create_animation('1DAbsorbingscalar.hdf5', '1DAbsorbingscalar.gif')
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/dirac_solver/storage.py:169, in create_animation(storage_path, output_path, interval)
#     166 anim = FuncAnimation(fig, update, frames=len(time_dset), interval=interval)
#     168 if output_path.endswith('.gif'):
# --> 169     anim.save(output_path, writer='imagemagick')
#     170 elif output_path.endswith('.mp4'):
#     171     anim.save(output_path, writer='ffmpeg')
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/animation.py:1098, in Animation.save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs, progress_callback)
#    1093     return a * np.array([r, g, b]) + 1 - a
#    1095 # canvas._is_saving = True makes the draw_event animation-starting
#    1096 # callback a no-op; canvas.manager = None prevents resizing the GUI
#    1097 # widget (both are likewise done in savefig()).
# -> 1098 with (writer.saving(self._fig, filename, dpi),
#    1099       cbook._setattr_cm(self._fig.canvas, _is_saving=True, manager=None)):
#    1100     if not writer._supports_transparency():
#    1101         facecolor = savefig_kwargs.get('facecolor',
#    1102                                        mpl.rcParams['savefig.facecolor'])
#
# File /usr/lib/python3.11/contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/animation.py:226, in AbstractMovieWriter.saving(self, fig, outfile, dpi, *args, **kwargs)
#     224     yield self
#     225 finally:
# --> 226     self.finish()
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/animation.py:328, in MovieWriter.finish(self)
#     326 def finish(self):
#     327     """Finish any processing for writing the movie."""
# --> 328     out, err = self._proc.communicate()
#     329     # Use the encoding/errors that universal_newlines would use.
#     330     out = TextIOWrapper(BytesIO(out)).read()
#
# File /usr/lib/python3.11/subprocess.py:1207, in Popen.communicate(self, input, timeout)
#    1204     endtime = None
#    1206 try:
# -> 1207     stdout, stderr = self._communicate(input, endtime, timeout)
#    1208 except KeyboardInterrupt:
#    1209     # https://bugs.python.org/issue25942
#    1210     # See the detailed comment in .wait().
#    1211     if timeout is not None:
#
# File /usr/lib/python3.11/subprocess.py:2059, in Popen._communicate(self, input, endtime, orig_timeout)
#    2052     self._check_timeout(endtime, orig_timeout,
#    2053                         stdout, stderr,
#    2054                         skip_check_and_raise=True)
#    2055     raise RuntimeError(  # Impossible :)
#    2056         '_check_timeout(..., skip_check_and_raise=True) '
#    2057         'failed to raise TimeoutExpired.')
# -> 2059 ready = selector.select(timeout)
#    2060 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    2062 # XXX Rewrite these to use non-blocking I/O on the file
#    2063 # objects; they are no longer using C stdio!
#
# File /usr/lib/python3.11/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:
# Error in callback <function _draw_all_if_interactive at 0x7f98eccda8e0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/pyplot.py:279, in _draw_all_if_interactive()
#     277 def _draw_all_if_interactive() -> None:
#     278     if matplotlib.is_interactive():
# --> 279         draw_all()
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/backends/backend_agg.py:382, in FigureCanvasAgg.draw(self)
#     379 # Acquire a lock on the shared font cache.
#     380 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381       else nullcontext()):
# --> 382     self.figure.draw(self.renderer)
#     383     # A GUI class may be need to update a window using this draw, so
#     384     # don't forget to call the superclass.
#     385     super().draw()
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/artist.py:94, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      92 @wraps(draw)
#      93 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94     result = draw(artist, renderer, *args, **kwargs)
#      95     if renderer._rasterizing:
#      96         renderer.stop_rasterizing()
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/artist.py:71, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      68     if artist.get_agg_filter() is not None:
#      69         renderer.start_filter()
# ---> 71     return draw(artist, renderer)
#      72 finally:
#      73     if artist.get_agg_filter() is not None:
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/figure.py:3264, in Figure.draw(self, renderer)
#    3261 finally:
#    3262     self.stale = False
# -> 3264 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/backend_bases.py:1189, in Event._process(self)
#    1187 def _process(self):
#    1188     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1189     self.canvas.callbacks.process(self.name, self)
#    1190     self.guiEvent = None
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/cbook.py:366, in CallbackRegistry.process(self, s, *args, **kwargs)
#     364 except Exception as exc:
#     365     if self.exception_handler is not None:
# --> 366         self.exception_handler(exc)
#     367     else:
#     368         raise
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/cbook.py:110, in _exception_printer(exc)
#     108 def _exception_printer(exc):
#     109     if _get_running_interactive_framework() in ["headless", None]:
# --> 110         raise exc
#     111     else:
#     112         traceback.print_exc()
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/cbook.py:361, in CallbackRegistry.process(self, s, *args, **kwargs)
#     359 if func is not None:
#     360     try:
# --> 361         func(*args, **kwargs)
#     362     # this does not capture KeyboardInterrupt, SystemExit,
#     363     # and GeneratorExit
#     364     except Exception as exc:
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/animation.py:928, in Animation._start(self, *args)
#     925 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     927 # Now do any initial draw
# --> 928 self._init_draw()
#     930 # Add our callback for stepping the animation and
#     931 # actually start the event_source.
#     932 self.event_source.add_callback(self._step)
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/animation.py:1770, in FuncAnimation._init_draw(self)
#    1762         warnings.warn(
#    1763             "Can not start iterating the frames for the initial draw. "
#    1764             "This can be caused by passing in a 0 length sequence "
#    (...)   1767             "it may be exhausted due to a previous display or save."
#    1768         )
#    1769         return
# -> 1770     self._draw_frame(frame_data)
#    1771 else:
#    1772     self._drawn_artists = self._init_func()
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/matplotlib/animation.py:1789, in FuncAnimation._draw_frame(self, framedata)
#    1785     self._save_seq = self._save_seq[-self._save_count:]
#    1787 # Call the func with framedata and args. If blitting is desired,
#    1788 # func needs to return a sequence of any artists that were modified.
# -> 1789 self._drawn_artists = self._func(framedata, *self._args)
#    1791 if self._blit:
#    1793     err = RuntimeError('The animation function must return a sequence '
#    1794                        'of Artist objects.')
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/dirac_solver/storage.py:126, in create_animation.<locals>.update(frame)
#     124 def update(frame):
#     125     ax.clear()
# --> 126     psi = psi_dset[frame]
#     127     rho = np.sum(np.conj(psi) * psi, axis=1).real
#     128     rho_grid = rho.reshape(grid_shape)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~/Documentos/universidad/semestre/noveno_semestre/desarrollo-de-software/entorno_virtual/lib/python3.11/site-packages/h5py/_hl/dataset.py:923, in Dataset.__getitem__(self, args, new_dtype)
#     921 mspace = h5s.create_simple(selection.mshape)
#     922 fspace = selection.id
# --> 923 self.id.read(mspace, fspace, arr, mtype, dxpl=self._dxpl)
#     925 # Patch up the output for NumPy
#     926 if arr.shape == ():
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5d.pyx:260, in h5py.h5d.DatasetID.read()
#
# File h5py/_proxy.pyx:113, in h5py._proxy.dset_rw()
#
# ValueError: Invalid dataset identifier (identifier is not of specified type)

# %%
# ==========================
# 1. Grid 1D
# ==========================
grid_1d = Grid(
    shape=(400,),         # 400 puntos
    spacing=(0.05,)       # dx = 0.05
)

# ==========================
# 2. Estado inicial
# ==========================
spinor = ConstantSpinor(momentum=[5.0, 0.0, 0.0])   # el p2 y p3 se ignoran
initial_state_1d = GaussianPacket(spinor, spatial_width=1.0)

# ==========================
# 3. Potencial 1D
# ==========================
def harmonic_1d(r):
    x = r[0]
    return 0.5 * x*x         # V(x) = x²/2

potential_1d = _core.ScalarPotential(harmonic_1d)

# ==========================
# 4. Frontera
# ==========================
boundary_1d = _core.PeriodicBoundary()

# ==========================
# 5. Construir el problema
# ==========================
builder_1d = DiracProblemBuilder()
problem_1d = (
    builder_1d
    .set_grid(grid_1d)
    .set_initial_state(initial_state_1d)
    .set_potential(potential_1d)
    .set_boundary_condition(boundary_1d)
    .set_time_parameters(time_step=0.01, total_time=10.0)
    .build()
)

# ==========================
# 6. Almacenamiento HDF5
# ==========================
storage_1d = HDF5Storage(
    filepath="1DPeriodicscalar.hdf5",
    problem=problem_1d
)

# ==========================
# 7. Ejecutar la simulación
# ==========================
solver_1d = DiracSolver(problem_1d)
solver_1d.run_simulation(storage_handler=storage_1d, save_every_n_steps=5)

# Cerrar archivo (por seguridad)
storage_1d.close()
create_animation('1DPeriodicscalar.hdf5', '1DPeriodicscalar.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 1DPeriodicscalar.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 0.13 segundos.
# Datos guardados y archivo cerrado: 1DPeriodicscalar.hdf5
# Animation saved to 1DPeriodicscalar.gif

# %%
# ==========================
# 1. Grid 1D
# ==========================
grid_1d = Grid(
    shape=(400,),         # 400 puntos
    spacing=(0.05,)       # dx = 0.05
)

# ==========================
# 2. Estado inicial
# ==========================
spinor = ConstantSpinor(momentum=[5.0, 0.0, 0.0])   # el p2 y p3 se ignoran
initial_state_1d = GaussianPacket(spinor, spatial_width=1.0)

# ==========================
# 3. Potencial 1D
# ==========================
def harmonic_1d(r):
    x = r[0]
    return 0.5 * x*x         # V(x) = x²/2

potential_1d = _core.FreeParticle()


# ==========================
# 4. Frontera
# ==========================
boundary_1d = _core.AbsorbingBoundary(strength=0.5)

# ==========================
# 5. Construir el problema
# ==========================
builder_1d = DiracProblemBuilder()
problem_1d = (
    builder_1d
    .set_grid(grid_1d)
    .set_initial_state(initial_state_1d)
    .set_potential(potential_1d)
    .set_boundary_condition(boundary_1d)
    .set_time_parameters(time_step=0.01, total_time=10.0)
    .build()
)

# ==========================
# 6. Almacenamiento HDF5
# ==========================
storage_1d = HDF5Storage(
    filepath="1DAbsorbingFree.hdf5",
    problem=problem_1d
)

# ==========================
# 7. Ejecutar la simulación
# ==========================
solver_1d = DiracSolver(problem_1d)
solver_1d.run_simulation(storage_handler=storage_1d, save_every_n_steps=5)

# Cerrar archivo (por seguridad)
storage_1d.close()
create_animation('1DAbsorbingFree.hdf5', '1DAbsorbingFree.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 1DAbsorbingFree.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 0.08 segundos.
# Datos guardados y archivo cerrado: 1DAbsorbingFree.hdf5
# Animation saved to 1DAbsorbingFree.gif

# %%
# ==========================
# 1. Grid 1D
# ==========================
grid_1d = Grid(
    shape=(400,),         # 400 puntos
    spacing=(0.05,)       # dx = 0.05
)

# ==========================
# 2. Estado inicial
# ==========================
spinor = ConstantSpinor(momentum=[5.0, 0.0, 0.0])   # el p2 y p3 se ignoran
initial_state_1d = GaussianPacket(spinor, spatial_width=1.0)

# ==========================
# 3. Potencial 1D
# ==========================
def harmonic_1d(r):
    x = r[0]
    return 0.5 * x*x         # V(x) = x²/2

potential_1d = _core.FreeParticle()

# ==========================
# 4. Frontera
# ==========================
boundary_1d = _core.PeriodicBoundary()

# ==========================
# 5. Construir el problema
# ==========================
builder_1d = DiracProblemBuilder()
problem_1d = (
    builder_1d
    .set_grid(grid_1d)
    .set_initial_state(initial_state_1d)
    .set_potential(potential_1d)
    .set_boundary_condition(boundary_1d)
    .set_time_parameters(time_step=0.01, total_time=10.0)
    .build()
)

# ==========================
# 6. Almacenamiento HDF5i
# ==========================
storage_1d = HDF5Storage(
    filepath="1DPeriodicFree.hdf5",
    problem=problem_1d
)

# ==========================
# 7. Ejecutar la simulación
# ==========================
solver_1d = DiracSolver(problem_1d)
solver_1d.run_simulation(storage_handler=storage_1d, save_every_n_steps=5)

# Cerrar archivo (por seguridad)
storage_1d.close()
create_animation('1DPeriodicFree.hdf5', '1DPeriodicFree.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 1DPeriodicFree.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 0.08 segundos.
# Datos guardados y archivo cerrado: 1DPeriodicFree.hdf5
# Animation saved to 1DPeriodicFree.gif

# %%
# ==========================
# 1. Grid 1D
# ==========================
grid_1d = Grid(
    shape=(400,),         # 400 puntos
    spacing=(0.05,)       # dx = 0.05
)

# ==========================
# 2. Estado inicial
# ==========================
spinor = ConstantSpinor(momentum=[5.0, 0.0, 0.0])   # el p2 y p3 se ignoran
initial_state_1d = GaussianPacket(spinor, spatial_width=1.0)

# ==========================
# 3. Potencial 1D
# ==========================
def harmonic_1d(r):
    x = r[0]
    return 0.5 * x*x         # V(x) = x²/2

potential_1d = _core.CoulombPotential(Z=1.0, epsilon=1e-6)


# ==========================
# 4. Frontera
# ==========================
boundary_1d = _core.AbsorbingBoundary(strength=0.5)

# ==========================
# 5. Construir el problema
# ==========================
builder_1d = DiracProblemBuilder()
problem_1d = (
    builder_1d
    .set_grid(grid_1d)
    .set_initial_state(initial_state_1d)
    .set_potential(potential_1d)
    .set_boundary_condition(boundary_1d)
    .set_time_parameters(time_step=0.01, total_time=10.0)
    .build()
)

# ==========================
# 6. Almacenamiento HDF5
# ==========================
storage_1d = HDF5Storage(
    filepath="1DAbsorbingC.hdf5",
    problem=problem_1d
)

# ==========================
# 7. Ejecutar la simulación
# ==========================
solver_1d = DiracSolver(problem_1d)
solver_1d.run_simulation(storage_handler=storage_1d, save_every_n_steps=5)

# Cerrar archivo (por seguridad)
storage_1d.close()
create_animation('1DAbsorbingC.hdf5', '1DAbsorbingC.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 1DAbsorbingC.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 0.09 segundos.
# Datos guardados y archivo cerrado: 1DAbsorbingC.hdf5
# Animation saved to 1DAbsorbingC.gif

# %%
# ==========================
# 1. Grid 1D
# ==========================
grid_1d = Grid(
    shape=(400,),         # 400 puntos
    spacing=(0.05,)       # dx = 0.05
)

# ==========================
# 2. Estado inicial
# ==========================
spinor = ConstantSpinor(momentum=[5.0, 0.0, 0.0])   # el p2 y p3 se ignoran
initial_state_1d = GaussianPacket(spinor, spatial_width=1.0)

# ==========================
# 3. Potencial 1D
# ==========================
def harmonic_1d(r):
    x = r[0]
    return 0.5 * x*x         # V(x) = x²/2

potential_1d =_core.CoulombPotential(Z=1.0, epsilon=1e-6)

# ==========================
# 4. Frontera
# ==========================
boundary_1d = _core.PeriodicBoundary()

# ==========================
# 5. Construir el problema
# ==========================
builder_1d = DiracProblemBuilder()
problem_1d = (
    builder_1d
    .set_grid(grid_1d)
    .set_initial_state(initial_state_1d)
    .set_potential(potential_1d)
    .set_boundary_condition(boundary_1d)
    .set_time_parameters(time_step=0.01, total_time=10.0)
    .build()
)

# ==========================
# 6. Almacenamiento HDF5i
# ==========================
storage_1d = HDF5Storage(
    filepath="1DPeriodicC.hdf5",
    problem=problem_1d
)

# ==========================
# 7. Ejecutar la simulación
# ==========================
solver_1d = DiracSolver(problem_1d)
solver_1d.run_simulation(storage_handler=storage_1d, save_every_n_steps=5)

# Cerrar archivo (por seguridad)
storage_1d.close()
create_animation('1DPeriodicC.hdf5', '1DPeriodicC.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 1DPeriodicC.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 0.08 segundos.
# Datos guardados y archivo cerrado: 1DPeriodicC.hdf5
# Animation saved to 1DPeriodicC.gif

# %% [markdown]
# ## 2D Simulation with periodic and absorbing  Boundary and each potential

# %%
grid_2d = Grid(shape=(100, 100), spacing=(0.1, 0.1))
constant_spinor_2d = ConstantSpinor(momentum=[10.0, 30.0, 0.0])
initial_state_2d = GaussianPacket(constant_spinor_2d, spatial_width=2.0)

def harmonic_2d(r):
    x, y = r
    return 0.5 * (x*x + y*y)

potential_2d = _core.ScalarPotential(harmonic_2d)

boundary_2d = _core.AbsorbingBoundary(strength=0.5, width=30)
builder_2d = DiracProblemBuilder()
problem_2d = (builder_2d
              .set_grid(grid_2d)
              .set_initial_state(initial_state_2d)
              .set_potential(potential_2d)
              .set_boundary_condition(boundary_2d)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_2d = HDF5Storage(filepath='2DAbsorbingscalar.hdf5', problem=problem_2d)
solver_2d = DiracSolver(problem_2d)
solver_2d.run_simulation(storage_handler=storage_2d, save_every_n_steps=10)
create_animation('2DAbsorbingscalar.hdf5', '2DAbsorbingscalar.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 2DAbsorbingscalar.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 2.76 segundos.
# Datos guardados y archivo cerrado: 2DAbsorbingscalar.hdf5
# Animation saved to 2DAbsorbingscalar.gif

# %%
grid_2d = Grid(shape=(100, 100), spacing=(0.1, 0.1))
constant_spinor_2d = ConstantSpinor(momentum=[10.0, 30.0, 0.0])
initial_state_2d = GaussianPacket(constant_spinor_2d, spatial_width=2.0)

def harmonic_2d(r):
    x, y = r
    return 0.5 * (x*x + y*y)

potential_2d = _core.ScalarPotential(harmonic_2d)

boundary_2d = _core.PeriodicBoundary()
builder_2d = DiracProblemBuilder()
problem_2d = (builder_2d
              .set_grid(grid_2d)
              .set_initial_state(initial_state_2d)
              .set_potential(potential_2d)
              .set_boundary_condition(boundary_2d)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_2d = HDF5Storage(filepath='2DPeriodicscalar.hdf5', problem=problem_2d)
solver_2d = DiracSolver(problem_2d)
solver_2d.run_simulation(storage_handler=storage_2d, save_every_n_steps=10)
create_animation('2DPeriodicscalar.hdf5', '2DPeriodicscalar.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 2DPeriodicscalar.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 2.25 segundos.
# Datos guardados y archivo cerrado: 2DPeriodicscalar.hdf5
# Animation saved to 2DPeriodicscalar.gif

# %% [markdown]
# ## 2D Simulation with Absorbing Boundary

# %%
from dirac_solver.initial_state import ConstantSpinor
grid_2d_abs = Grid(shape=(100, 100), spacing=(0.1, 0.1))
constant_spinor_2d_abs = ConstantSpinor(momentum=[10.0, 30.0, 0.0])
initial_state_2d_abs = GaussianPacket(constant_spinor_2d_abs, spatial_width=2.0)
potential_2d_abs = _core.FreeParticle()
boundary_2d_abs = _core.AbsorbingBoundary(strength=0.5)
builder_2d_abs = DiracProblemBuilder()
problem_2d_abs = (builder_2d_abs
              .set_grid(grid_2d_abs)
              .set_initial_state(initial_state_2d_abs)
              .set_potential(potential_2d_abs)
              .set_boundary_condition(boundary_2d_abs)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_2d_abs = HDF5Storage(filepath='2DAbsorbingFree.hdf5', problem=problem_2d_abs)
solver_2d_abs = DiracSolver(problem_2d_abs)
solver_2d_abs.run_simulation(storage_handler=storage_2d_abs, save_every_n_steps=10)
create_animation('2DAbsorbingFree.hdf5', '2DAbsorbingFree.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 2DAbsorbingFree.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 0.87 segundos.
# Datos guardados y archivo cerrado: 2DAbsorbingFree.hdf5
# Animation saved to 2DAbsorbingFree.gif

# %%
from dirac_solver.initial_state import ConstantSpinor
grid_2d_abs = Grid(shape=(100, 100), spacing=(0.1, 0.1))
constant_spinor_2d_abs = ConstantSpinor(momentum=[10.0, 30.0, 0.0])
initial_state_2d_abs = GaussianPacket(constant_spinor_2d_abs, spatial_width=2.0)
potential_2d_abs = _core.FreeParticle()
boundary_2d_abs = _core.PeriodicBoundary()
builder_2d_abs = DiracProblemBuilder()
problem_2d_abs = (builder_2d_abs
              .set_grid(grid_2d_abs)
              .set_initial_state(initial_state_2d_abs)
              .set_potential(potential_2d_abs)
              .set_boundary_condition(boundary_2d_abs)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_2d_abs = HDF5Storage(filepath='2DPeriodicFree.hdf5', problem=problem_2d_abs)
solver_2d_abs = DiracSolver(problem_2d_abs)
solver_2d_abs.run_simulation(storage_handler=storage_2d_abs, save_every_n_steps=10)
create_animation('2DPeriodicFree.hdf5', '2DPeriodicFree.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 2DPeriodicFree.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 0.92 segundos.
# Datos guardados y archivo cerrado: 2DPeriodicFree.hdf5
# Animation saved to 2DPeriodicFree.gif

# %%
from dirac_solver.initial_state import ConstantSpinor
grid_2d_abs = Grid(shape=(100, 100), spacing=(0.1, 0.1))
constant_spinor_2d_abs = ConstantSpinor(momentum=[10.0, 30.0, 0.0])
initial_state_2d_abs = GaussianPacket(constant_spinor_2d_abs, spatial_width=2.0)
potential_2d_abs = _core.CoulombPotential(Z=1.0, epsilon=1e-6)
boundary_2d_abs = _core.AbsorbingBoundary(strength=0.5)
builder_2d_abs = DiracProblemBuilder()
problem_2d_abs = (builder_2d_abs
              .set_grid(grid_2d_abs)
              .set_initial_state(initial_state_2d_abs)
              .set_potential(potential_2d_abs)
              .set_boundary_condition(boundary_2d_abs)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_2d_abs = HDF5Storage(filepath='2DAbsorbingC.hdf5', problem=problem_2d_abs)
solver_2d_abs = DiracSolver(problem_2d_abs)
solver_2d_abs.run_simulation(storage_handler=storage_2d_abs, save_every_n_steps=10)
create_animation('2DAbsorbingC.hdf5', '2DAbsorbingC.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 2DAbsorbingC.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 1.05 segundos.
# Datos guardados y archivo cerrado: 2DAbsorbingC.hdf5
# Animation saved to 2DAbsorbingC.gif

# %%
from dirac_solver.initial_state import ConstantSpinor
grid_2d_abs = Grid(shape=(100, 100), spacing=(0.1, 0.1))
constant_spinor_2d_abs = ConstantSpinor(momentum=[10.0, 30.0, 0.0])
initial_state_2d_abs = GaussianPacket(constant_spinor_2d_abs, spatial_width=2.0)
potential_2d_abs = _core.CoulombPotential(Z=1.0, epsilon=1e-6)
boundary_2d_abs = _core.PeriodicBoundary()
builder_2d_abs = DiracProblemBuilder()
problem_2d_abs = (builder_2d_abs
              .set_grid(grid_2d_abs)
              .set_initial_state(initial_state_2d_abs)
              .set_potential(potential_2d_abs)
              .set_boundary_condition(boundary_2d_abs)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_2d_abs = HDF5Storage(filepath='2DPeriodicC.hdf5', problem=problem_2d_abs)
solver_2d_abs = DiracSolver(problem_2d_abs)
solver_2d_abs.run_simulation(storage_handler=storage_2d_abs, save_every_n_steps=10)
create_animation('2DPeriodicC.hdf5', '2DPeriodicC.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 2DPeriodicC.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 1.09 segundos.
# Datos guardados y archivo cerrado: 2DPeriodicC.hdf5
# Animation saved to 2DPeriodicC.gif

# %% [markdown]
# ## 3D Simulation with periodic and absorbing  Boundary and each potential

# %%
grid_3d = Grid(shape=(50, 50, 50), spacing=(0.2, 0.2, 0.2))
constant_spinor_3d = ConstantSpinor(momentum=[5.0, 10.0, 0.0])
initial_state_3d = GaussianPacket(constant_spinor_3d, spatial_width=1.0)

def harmonic_3d(r):
    x, y, z = r
    return 0.5 * (x*x + y*y + z*z)

potential_3d = _core.ScalarPotential(harmonic_3d)


boundary_3d = _core.PeriodicBoundary()
builder_3d = DiracProblemBuilder()
problem_3d = (builder_3d
              .set_grid(grid_3d)
              .set_initial_state(initial_state_3d)
              .set_potential(potential_3d)
              .set_boundary_condition(boundary_3d)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_3d = HDF5Storage(filepath='3DPeriodicscalar.hdf5', problem=problem_3d)
solver_3d = DiracSolver(problem_3d)
solver_3d.run_simulation(storage_handler=storage_3d, save_every_n_steps=10)
create_animation('3DPeriodicscalar.hdf5', '3DPeriodicscalar.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 3DPeriodicscalar.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 37.76 segundos.
# Datos guardados y archivo cerrado: 3DPeriodicscalar.hdf5
# Animation saved to 3DPeriodicscalar.gif

# %%
grid_3d = Grid(shape=(50, 50, 50), spacing=(0.2, 0.2, 0.2))
constant_spinor_3d = ConstantSpinor(momentum=[5.0, 10.0, 0.0])
initial_state_3d = GaussianPacket(constant_spinor_3d, spatial_width=1.0)

def harmonic_3d(r):
    x, y, z = r
    return 0.5 * (x*x + y*y + z*z)

potential_3d = _core.ScalarPotential(harmonic_3d)


boundary_3d = _core.AbsorbingBoundary(strength=0.5)
builder_3d = DiracProblemBuilder()
problem_3d = (builder_3d
              .set_grid(grid_3d)
              .set_initial_state(initial_state_3d)
              .set_potential(potential_3d)
              .set_boundary_condition(boundary_3d)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_3d = HDF5Storage(filepath='3DAbsorbingscalar.hdf5', problem=problem_3d)
solver_3d = DiracSolver(problem_3d)
solver_3d.run_simulation(storage_handler=storage_3d, save_every_n_steps=10)
create_animation('3DAbsorbingscalar.hdf5', '3DAbsorbingscalar.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 3DAbsorbingscalar.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 36.35 segundos.
# Datos guardados y archivo cerrado: 3DAbsorbingscalar.hdf5
# Animation saved to 3DAbsorbingscalar.gif

# %%
grid_3d = Grid(shape=(50, 50, 50), spacing=(0.2, 0.2, 0.2))
constant_spinor_3d = ConstantSpinor(momentum=[5.0, 10.0, 0.0])
initial_state_3d = GaussianPacket(constant_spinor_3d, spatial_width=1.0)


potential_3d = _core.FreeParticle()


boundary_3d = _core.PeriodicBoundary()
builder_3d = DiracProblemBuilder()
problem_3d = (builder_3d
              .set_grid(grid_3d)
              .set_initial_state(initial_state_3d)
              .set_potential(potential_3d)
              .set_boundary_condition(boundary_3d)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_3d = HDF5Storage(filepath='3DPeriodicFree.hdf5', problem=problem_3d)
solver_3d = DiracSolver(problem_3d)
solver_3d.run_simulation(storage_handler=storage_3d, save_every_n_steps=10)
create_animation('3DPeriodicFree.hdf5', '3DPeriodicFree.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 3DPeriodicFree.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 14.73 segundos.
# Datos guardados y archivo cerrado: 3DPeriodicFree.hdf5
# Animation saved to 3DPeriodicFree.gif

# %%
grid_3d = Grid(shape=(50, 50, 50), spacing=(0.2, 0.2, 0.2))
constant_spinor_3d = ConstantSpinor(momentum=[5.0, 10.0, 0.0])
initial_state_3d = GaussianPacket(constant_spinor_3d, spatial_width=1.0)


potential_3d = _core.FreeParticle()


boundary_3d = _core.AbsorbingBoundary(strength=0.5)
builder_3d = DiracProblemBuilder()
problem_3d = (builder_3d
              .set_grid(grid_3d)
              .set_initial_state(initial_state_3d)
              .set_potential(potential_3d)
              .set_boundary_condition(boundary_3d)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_3d = HDF5Storage(filepath='3DAbsorbingFree.hdf5', problem=problem_3d)
solver_3d = DiracSolver(problem_3d)
solver_3d.run_simulation(storage_handler=storage_3d, save_every_n_steps=10)
create_animation('3DAbsorbingFree.hdf5', '3DAbsorbingFree.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: 3DAbsorbingFree.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
#   Paso 260/1000 completado.
#   Paso 270/1000 completado.
#   Paso 280/1000 completado.
#   Paso 290/1000 completado.
#   Paso 300/1000 completado.
#   Paso 310/1000 completado.
#   Paso 320/1000 completado.
#   Paso 330/1000 completado.
#   Paso 340/1000 completado.
#   Paso 350/1000 completado.
#   Paso 360/1000 completado.
#   Paso 370/1000 completado.
#   Paso 380/1000 completado.
#   Paso 390/1000 completado.
#   Paso 400/1000 completado.
#   Paso 410/1000 completado.
#   Paso 420/1000 completado.
#   Paso 430/1000 completado.
#   Paso 440/1000 completado.
#   Paso 450/1000 completado.
#   Paso 460/1000 completado.
#   Paso 470/1000 completado.
#   Paso 480/1000 completado.
#   Paso 490/1000 completado.
#   Paso 500/1000 completado.
#   Paso 510/1000 completado.
#   Paso 520/1000 completado.
#   Paso 530/1000 completado.
#   Paso 540/1000 completado.
#   Paso 550/1000 completado.
#   Paso 560/1000 completado.
#   Paso 570/1000 completado.
#   Paso 580/1000 completado.
#   Paso 590/1000 completado.
#   Paso 600/1000 completado.
#   Paso 610/1000 completado.
#   Paso 620/1000 completado.
#   Paso 630/1000 completado.
#   Paso 640/1000 completado.
#   Paso 650/1000 completado.
#   Paso 660/1000 completado.
#   Paso 670/1000 completado.
#   Paso 680/1000 completado.
#   Paso 690/1000 completado.
#   Paso 700/1000 completado.
#   Paso 710/1000 completado.
#   Paso 720/1000 completado.
#   Paso 730/1000 completado.
#   Paso 740/1000 completado.
#   Paso 750/1000 completado.
#   Paso 760/1000 completado.
#   Paso 770/1000 completado.
#   Paso 780/1000 completado.
#   Paso 790/1000 completado.
#   Paso 800/1000 completado.
#   Paso 810/1000 completado.
#   Paso 820/1000 completado.
#   Paso 830/1000 completado.
#   Paso 840/1000 completado.
#   Paso 850/1000 completado.
#   Paso 860/1000 completado.
#   Paso 870/1000 completado.
#   Paso 880/1000 completado.
#   Paso 890/1000 completado.
#   Paso 900/1000 completado.
#   Paso 910/1000 completado.
#   Paso 920/1000 completado.
#   Paso 930/1000 completado.
#   Paso 940/1000 completado.
#   Paso 950/1000 completado.
#   Paso 960/1000 completado.
#   Paso 970/1000 completado.
#   Paso 980/1000 completado.
#   Paso 990/1000 completado.
#   Paso 1000/1000 completado.
# Simulación finalizada en 15.23 segundos.
# Datos guardados y archivo cerrado: 3DAbsorbingFree.hdf5
# Animation saved to 3DAbsorbingFree.gif

# %%
grid_3d = Grid(shape=(50, 50, 50), spacing=(0.2, 0.2, 0.2))
constant_spinor_3d = ConstantSpinor(momentum=[5.0, 10.0, 0.0])
initial_state_3d = GaussianPacket(constant_spinor_3d, spatial_width=1.0)


potential_3d = _core._core.CoulombPotential(Z=1.0, epsilon=1e-6)


boundary_3d = _core.PeriodicBoundary()
builder_3d = DiracProblemBuilder()
problem_3d = (builder_3d
              .set_grid(grid_3d)
              .set_initial_state(initial_state_3d)
              .set_potential(potential_3d)
              .set_boundary_condition(boundary_3d)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_3d = HDF5Storage(filepath='3DPeriodicC.hdf5', problem=problem_3d)
solver_3d = DiracSolver(problem_3d)
solver_3d.run_simulation(storage_handler=storage_3d, save_every_n_steps=10)
create_animation('3DPeriodicC.hdf5', '3DPeriodicC.gif')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 6
#       2 constant_spinor_3d = ConstantSpinor(momentum=[5.0, 10.0, 0.0])
#       3 initial_state_3d = GaussianPacket(constant_spinor_3d, spatial_width=1.0)
# ----> 6 potential_3d = _core._core.CoulombPotential(Z=1.0, epsilon=1e-6)
#       9 boundary_3d = _core.PeriodicBoundary()
#      10 builder_3d = DiracProblemBuilder()
#
# AttributeError: module 'dirac_solver._core' has no attribute '_core'

# %%
grid_3d = Grid(shape=(50, 50, 50), spacing=(0.2, 0.2, 0.2))
constant_spinor_3d = ConstantSpinor(momentum=[5.0, 10.0, 0.0])
initial_state_3d = GaussianPacket(constant_spinor_3d, spatial_width=1.0)


potential_3d = _core._core.CoulombPotential(Z=1.0, epsilon=1e-6)


boundary_3d = _core.AbsorbingBoundary(strength=0.5)
builder_3d = DiracProblemBuilder()
problem_3d = (builder_3d
              .set_grid(grid_3d)
              .set_initial_state(initial_state_3d)
              .set_potential(potential_3d)
              .set_boundary_condition(boundary_3d)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_3d = HDF5Storage(filepath='3DAbsorbingC.hdf5', problem=problem_3d)
solver_3d = DiracSolver(problem_3d)
solver_3d.run_simulation(storage_handler=storage_3d, save_every_n_steps=10)
create_animation('3DAbsorbingC.hdf5', '3DAbsorbingC.gif')
