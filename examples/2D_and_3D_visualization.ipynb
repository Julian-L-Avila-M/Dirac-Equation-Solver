# %% [markdown]
# # 2D and 3D Simulation and Visualization

# %%
import numpy as np
import matplotlib.pyplot as plt
from dirac_solver.geometry import Grid
from dirac_solver.initial_state import GaussianPacket
from dirac_solver.core import DiracSolver, DiracProblemBuilder
from dirac_solver.storage import HDF5Storage
from dirac_solver import _core, electron_mass

# %% [markdown]
# ## 2D Simulation with Periodic Boundary

# %%
from dirac_solver.initial_state import ConstantSpinor
grid_2d = Grid(shape=(100, 100), spacing=(0.1, 0.1))
constant_spinor_2d = ConstantSpinor(momentum=[10.0, 30.0, 0.0])
initial_state_2d = GaussianPacket(constant_spinor_2d, spatial_width=2.0)
potential_2d = _core.FreeParticle()
boundary_2d = _core.PeriodicBoundary()
builder_2d = DiracProblemBuilder()
problem_2d = (builder_2d
              .set_grid(grid_2d)
              .set_initial_state(initial_state_2d)
              .set_potential(potential_2d)
              .set_boundary_condition(boundary_2d)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_2d = HDF5Storage(filepath='temp_2d_periodic_simulation.hdf5', problem=problem_2d)
solver_2d = DiracSolver(problem_2d)
solver_2d.run_simulation(storage_handler=storage_2d, save_every_n_steps=10)
# Out:
# HDF5Storage inicializado. Guardando datos en: temp_2d_periodic_simulation.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
# ...

# %%
solver_2d.plot_probability_density()
# Out:
# Graficando densidad de probabilidad...

# %% [markdown]
# ## 2D Simulation with Absorbing Boundary

# %%
from dirac_solver.initial_state import ConstantSpinor
grid_2d_abs = Grid(shape=(100, 100), spacing=(0.1, 0.1))
constant_spinor_2d_abs = ConstantSpinor(momentum=[10.0, 30.0, 0.0])
initial_state_2d_abs = GaussianPacket(constant_spinor_2d_abs, spatial_width=2.0)
potential_2d_abs = _core.FreeParticle()
boundary_2d_abs = _core.AbsorbingBoundary(strength=0.5)
builder_2d_abs = DiracProblemBuilder()
problem_2d_abs = (builder_2d_abs
              .set_grid(grid_2d_abs)
              .set_initial_state(initial_state_2d_abs)
              .set_potential(potential_2d_abs)
              .set_boundary_condition(boundary_2d_abs)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_2d_abs = HDF5Storage(filepath='temp_2d_absorbing_simulation.hdf5', problem=problem_2d_abs)
solver_2d_abs = DiracSolver(problem_2d_abs)
solver_2d_abs.run_simulation(storage_handler=storage_2d_abs, save_every_n_steps=10)
# Out:
# HDF5Storage inicializado. Guardando datos en: temp_2d_absorbing_simulation.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
# ...

# %%
solver_2d_abs.plot_probability_density()
# Out:
# Graficando densidad de probabilidad...

# %% [markdown]
# ## 3D Simulation with Periodic Boundary

# %%
grid_3d = Grid(shape=(50, 50, 50), spacing=(0.2, 0.2, 0.2))
constant_spinor_3d = ConstantSpinor(momentum=[5.0, 10.0, 0.0])
initial_state_3d = GaussianPacket(constant_spinor_3d, spatial_width=1.0)
potential_3d = _core.FreeParticle()
boundary_3d = _core.PeriodicBoundary()
builder_3d = DiracProblemBuilder()
problem_3d = (builder_3d
              .set_grid(grid_3d)
              .set_initial_state(initial_state_3d)
              .set_potential(potential_3d)
              .set_boundary_condition(boundary_3d)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_3d = HDF5Storage(filepath='temp_3d_periodic_simulation.hdf5', problem=problem_3d)
solver_3d = DiracSolver(problem_3d)
solver_3d.run_simulation(storage_handler=storage_3d, save_every_n_steps=10)
# Out:
# HDF5Storage inicializado. Guardando datos en: temp_3d_periodic_simulation.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
# ...

# %%
solver_3d.plot_probability_density()
# Out:
# Graficando densidad de probabilidad...

# %% [markdown]
# ## 3D Simulation with Absorbing Boundary

# %%
grid_3d_abs = Grid(shape=(50, 50, 50), spacing=(0.2, 0.2, 0.2))
constant_spinor_3d_abs = ConstantSpinor(momentum=[5.0, 10.0, 0.0])
initial_state_3d_abs = GaussianPacket(constant_spinor_3d_abs, spatial_width=1.0)
potential_3d_abs = _core.FreeParticle()
boundary_3d_abs = _core.AbsorbingBoundary(strength=0.5)
builder_3d_abs = DiracProblemBuilder()
problem_3d_abs = (builder_3d_abs
              .set_grid(grid_3d_abs)
              .set_initial_state(initial_state_3d_abs)
              .set_potential(potential_3d_abs)
              .set_boundary_condition(boundary_3d_abs)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_3d_abs = HDF5Storage(filepath='temp_3d_absorbing_simulation.hdf5', problem=problem_3d_abs)
solver_3d_abs = DiracSolver(problem_3d_abs)
solver_3d_abs.run_simulation(storage_handler=storage_3d_abs, save_every_n_steps=10)
# Out:
# HDF5Storage inicializado. Guardando datos en: temp_3d_absorbing_simulation.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
# ...

# %%
solver_3d_abs.plot_probability_density()
# Out:
# Graficando densidad de probabilidad...

# %% [markdown]
# ## Animation Generation

# %%
from dirac_solver.storage import create_animation
create_animation('temp_2d_periodic_simulation.hdf5', '2d_periodic_simulation.gif')
create_animation('temp_2d_absorbing_simulation.hdf5', '2d_absorbing_simulation.gif')
create_animation('temp_3d_periodic_simulation.hdf5', '3d_periodic_simulation.gif')
create_animation('temp_3d_absorbing_simulation.hdf5', '3d_absorbing_simulation.gif')
# Out:
# Animation saved to 2d_periodic_simulation.gif
# Animation saved to 2d_absorbing_simulation.gif
# Animation saved to 3d_periodic_simulation.gif
# Animation saved to 3d_absorbing_simulation.gif

# %%
grid_2d = Grid(shape=(400, 400), spacing=(0.1, 0.1))
constant_spinor_2d = ConstantSpinor(momentum=[0.0, 0.0, 0.0])
initial_state_2d = GaussianPacket(constant_spinor_2d, spatial_width=4.0)
potentialC_2d = _core.CoulombPotential(Z=1.0, epsilon=1e-6)
boundary_2d_abs = _core.AbsorbingBoundary(strength=0.5)
builder_2d = DiracProblemBuilder()
problemC_2d = (builder_2d
              .set_grid(grid_2d)
              .set_initial_state(initial_state_2d)
              .set_potential(potentialC_2d)
              .set_boundary_condition(boundary_2d)
              .set_time_parameters(time_step=0.01, total_time=10.0)
              .build())
storage_2d = HDF5Storage(filepath='temp_2dC_periodic_simulation.hdf5', problem=problemC_2d)
solver_2d = DiracSolver(problemC_2d)
solver_2d.run_simulation(storage_handler=storage_2d, save_every_n_steps=10)
create_animation('temp_2dC_periodic_simulation.hdf5', '2d_periodicC_simulation.gif')
# Out:
# HDF5Storage inicializado. Guardando datos en: temp_2dC_periodic_simulation.hdf5
# DiracSolver inicializado con el motor C++ 'FDTDLeapfrogIntegrator'.
# Ejecutando simulación por 1000 pasos...
# Guardando snapshot inicial (t=0.0).
#   Paso 10/1000 completado.
#   Paso 20/1000 completado.
#   Paso 30/1000 completado.
#   Paso 40/1000 completado.
#   Paso 50/1000 completado.
#   Paso 60/1000 completado.
#   Paso 70/1000 completado.
#   Paso 80/1000 completado.
#   Paso 90/1000 completado.
#   Paso 100/1000 completado.
#   Paso 110/1000 completado.
#   Paso 120/1000 completado.
#   Paso 130/1000 completado.
#   Paso 140/1000 completado.
#   Paso 150/1000 completado.
#   Paso 160/1000 completado.
#   Paso 170/1000 completado.
#   Paso 180/1000 completado.
#   Paso 190/1000 completado.
#   Paso 200/1000 completado.
#   Paso 210/1000 completado.
#   Paso 220/1000 completado.
#   Paso 230/1000 completado.
#   Paso 240/1000 completado.
#   Paso 250/1000 completado.
# ...

# %%
create_animation('temp_2d_absorbing_simulation.hdf5', '2d_absorbing_simulation.gif')
# Out:
# Animation saved to 2d_absorbing_simulation.gif
